# %%
import os 
import pandas as pd
from matplotlib import pyplot as plt

# %%
Home = os.getcwd()
Main = os.path.join(Home,'Main_Result')
Supp = os.path.join(Home,'Supplementary_Result')

# %%
Main_files = [os.path.join(Main,i) for i in os.listdir(Main)]

# %%
df = pd.read_csv(Main_files[3])
Main_files[3]
# Out:
# 'c:\\Users\\chand\\Desktop\\temp_here\\Green-Computing\\kid_tries\\full\\Main_Result\\Cuckoo Search.csv'

# %%
df
# Out:
#     Unnamed: 0        ID  Accuracy  Time Taken (s)  Energy Used (J)  \
# 0            0  CUC-0000    0.8970              25             95.4
# 1            1  CUC-0001    0.8945             180            630.1
# 2            2  CUC-0002    0.8940              15             54.6
# 3            3  CUC-0003    0.8965             106            478.5
# 4            4  CUC-0004    0.8985             104            375.6
# ..         ...       ...       ...             ...              ...
# 95          95  CUC-0095    0.8975              33            110.4
# 96          96  CUC-0096    0.8980             296            989.1
# 97          97  CUC-0097    0.8970               9             29.9
# 98          98  CUC-0098    0.8970              89            297.7
# 99          99  CUC-0099    0.8985              92            300.5
#
#     Equivalent CO2 Emission (mg)
# 0                      22.525000
# 1                     148.773611
# 2                      12.891667
# 3                     112.979167
# 4                      88.683333
# ..                           ...
# 95                     26.066667
# 96                    233.537500
# 97                      7.059722
# 98                     70.290278
# 99                     70.951389
#
# [100 rows x 6 columns]

# %%
for curr_file in Main_files:
    df = pd.read_csv(curr_file)
    df_cols = [i for i in df.columns if not i.startswith('Unnamed')]
    #print(curr_file)
    #print(df_cols)
    df['Accuracy'] *= 100
    new_df = pd.DataFrame()
    for col_name in df_cols:
        new_df[col_name] = df[col_name]
    new_df.to_csv(curr_file)
# Out:
# c:\Users\chand\Desktop\temp_here\Green-Computing\kid_tries\full\Main_Result\Base.csv
# ['ID', 'Accuracy', 'Time Taken (s)', 'Energy Used (J)', 'Equivalent CO2 Emission (mg)']
# c:\Users\chand\Desktop\temp_here\Green-Computing\kid_tries\full\Main_Result\Bat.csv
# ['ID', 'Accuracy', 'Time Taken (s)', 'Energy Used (J)', 'Equivalent CO2 Emission (mg)']
# c:\Users\chand\Desktop\temp_here\Green-Computing\kid_tries\full\Main_Result\Camel Algorithm.csv
# ['ID', 'Accuracy', 'Time Taken (s)', 'Energy Used (J)', 'Equivalent CO2 Emission (mg)']
# c:\Users\chand\Desktop\temp_here\Green-Computing\kid_tries\full\Main_Result\Cuckoo Search.csv
# ['ID', 'Accuracy', 'Time Taken (s)', 'Energy Used (J)', 'Equivalent CO2 Emission (mg)']
# c:\Users\chand\Desktop\temp_here\Green-Computing\kid_tries\full\Main_Result\Fire Fly.csv
# ['ID', 'Accuracy', 'Time Taken (s)', 'Energy Used (J)', 'Equivalent CO2 Emission (mg)']
# c:\Users\chand\Desktop\temp_here\Green-Computing\kid_tries\full\Main_Result\Particle Swarm.csv
# ['ID', 'Accuracy', 'Time Taken (s)', 'Energy Used (J)', 'Equivalent CO2 Emission (mg)']
# c:\Users\chand\Desktop\temp_here\Green-Computing\kid_tries\full\Main_Result\Self Adaptive Bat.csv
# ['ID', 'Accuracy', 'Time Taken (s)', 'Energy Used (J)', 'Equivalent CO2 Emission (mg)']

# %%
Supp_files = [os.path.join(Supp,i) for i in os.listdir(Supp)]
Supp_files
# Out:
# ['c:\\Users\\chand\\Desktop\\temp_here\\Green-Computing\\kid_tries\\full\\Supplementary_Result\\Base_Energy_Distribution.csv',
#  'c:\\Users\\chand\\Desktop\\temp_here\\Green-Computing\\kid_tries\\full\\Supplementary_Result\\Bat_Energy_Distribution.csv',
#  'c:\\Users\\chand\\Desktop\\temp_here\\Green-Computing\\kid_tries\\full\\Supplementary_Result\\Bat_Iterations.svg',
#  'c:\\Users\\chand\\Desktop\\temp_here\\Green-Computing\\kid_tries\\full\\Supplementary_Result\\Bat_Parameter.csv',
#  'c:\\Users\\chand\\Desktop\\temp_here\\Green-Computing\\kid_tries\\full\\Supplementary_Result\\Camel Algorithm_Energy_Distribution.csv',
#  'c:\\Users\\chand\\Desktop\\temp_here\\Green-Computing\\kid_tries\\full\\Supplementary_Result\\Camel Algorithm_Iterations.svg',
#  'c:\\Users\\chand\\Desktop\\temp_here\\Green-Computing\\kid_tries\\full\\Supplementary_Result\\Camel Algorithm_Parameter.csv',
#  'c:\\Users\\chand\\Desktop\\temp_here\\Green-Computing\\kid_tries\\full\\Supplementary_Result\\Cuckoo Search_Energy_Distribution.csv',
#  'c:\\Users\\chand\\Desktop\\temp_here\\Green-Computing\\kid_tries\\full\\Supplementary_Result\\Cuckoo Search_Iterations.svg',
#  'c:\\Users\\chand\\Desktop\\temp_here\\Green-Computing\\kid_tries\\full\\Supplementary_Result\\Cuckoo Search_Parameter.csv',
#  'c:\\Users\\chand\\Desktop\\temp_here\\Green-Computing\\kid_tries\\full\\Supplementary_Result\\Fire Fly_Energy_Distribution.csv',
#  'c:\\Users\\chand\\Desktop\\temp_here\\Green-Computing\\kid_tries\\full\\Supplementary_Result\\Fire Fly_Iterations.svg',
#  'c:\\Users\\chand\\Desktop\\temp_here\\Green-Computing\\kid_tries\\full\\Supplementary_Result\\Fire Fly_Parameter.csv',
#  'c:\\Users\\chand\\Desktop\\temp_here\\Green-Computing\\kid_tries\\full\\Supplementary_Result\\Particle Swarm_Energy_Distribution.csv',
#  'c:\\Users\\chand\\Desktop\\temp_here\\Green-Computing\\kid_tries\\full\\Supplementary_Result\\Particle Swarm_Iterations.svg',
#  'c:\\Users\\chand\\Desktop\\temp_here\\Green-Computing\\kid_tries\\full\\Supplementary_Result\\Particle Swarm_Parameter.csv',
#  'c:\\Users\\chand\\Desktop\\temp_here\\Green-Computing\\kid_tries\\full\\Supplementary_Result\\Self Adaptive Bat_Energy_Distribution.csv',
#  'c:\\Users\\chand\\Desktop\\temp_here\\Green-Computing\\kid_tries\\full\\Supplementary_Result\\Self Adaptive Bat_Iterations.svg',
#  'c:\\Users\\chand\\Desktop\\temp_here\\Green-Computing\\kid_tries\\full\\Supplementary_Result\\Self Adaptive Bat_Parameter.csv']

# %%
temp = [ os.path.join(Home,i) for i in os.listdir(Home) if i.endswith('.svg')]
for i in temp:
    os.remove(i)

# %%
graphs = [i for i in Supp_files if i.endswith('.svg')]
print('graphs')
for i in graphs:
    os.remove
for curr_file in os.listdir(Main):
    if curr_file == 'Base.csv':
        print('Just passed Base')
        continue
    df = pd.read_csv(os.path.join(Main,curr_file))
    Acc = df['Accuracy']
    plt.close()
    plt.plot(range(len(Acc)),Acc,'-o')
    plt.grid(True)
    plt.xlabel("Iteration Number")
    plt.ylabel("Accuracy")
    plt.savefig(os.path.join(Supp,f"{curr_file.split('.')[0]}_Iterations.svg"), format='SVG')
# Out:
# graphs
# Just passed Base
